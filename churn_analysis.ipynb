# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the dataset
df = pd.read_csv('../data/Telco-Customer-Churn.csv')  # Adjust the path if needed

# Step 3: View basic info
print("Shape of dataset:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Step 1: Import necessary libraries
# ----> 2 import pandas as pd
#       4 # Step 2: Load the dataset
#       5 df = pd.read_csv('../data/Telco-Customer-Churn.csv')  # Adjust the path if needed
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 20.5 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 19.2 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the dataset
df = pd.read_csv('../data/Telco-Customer-Churn.csv')  # Adjust the path if needed

# Step 3: View basic info
print("Shape of dataset:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 import pandas as pd
#       4 # Step 2: Load the dataset
# ----> 5 df = pd.read_csv('../data/Telco-Customer-Churn.csv')  # Adjust the path if needed
#       7 # Step 3: View basic info
#       8 print("Shape of dataset:", df.shape)
#
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the dataset
df = pd.read_csv('Telco-Customer-Churn.csv')  # Adjust the path if needed

# Step 3: View basic info
print("Shape of dataset:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 import pandas as pd
#       4 # Step 2: Load the dataset
# ----> 5 df = pd.read_csv('Telco-Customer-Churn.csv')  # Adjust the path if needed
#       7 # Step 3: View basic info
#       8 print("Shape of dataset:", df.shape)
#
# ...

# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the dataset
df = pd.read_csv('Users/imran/Downloads/Telco-Customer-Churn.csv')  # Adjust the path if needed

# Step 3: View basic info
print("Shape of dataset:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       2 import pandas as pd
#       4 # Step 2: Load the dataset
# ----> 5 df = pd.read_csv('Users/imran/Downloads/Telco-Customer-Churn.csv')  # Adjust the path if needed
#       7 # Step 3: View basic info
#       8 print("Shape of dataset:", df.shape)
#
# ...
